# %% [markdown]
# # 📊 Day 4: Exploratory Data Analysis (EDA)
#
# **Author:** Vidhi Pandey
# **Date:** June 2025
# **Goal:** Learn data visualization using Matplotlib and Seaborn for basic EDA.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: make plots look better
sns.set(style="whitegrid")

# %%
df = pd.read_csv("students_data.csv")
print(df.head())
# Out:
#     Name  Age    Subject  Marks Grade
# 0  Vidhi   24       Math     88     B
# 1  Aryan   23    Physics     79     C
# 2   Neha   22  Chemistry     91     A
# 3    Raj   25       Math     85     B
# 4  Tanya   21         CS     95     A

# %%
# Plot student marks with a line plot
plt.figure(figsize=(8, 4))
plt.plot(df["Name"], df["Marks"], marker='o', linestyle='-', color='blue')
plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.bar(df["Name"], df["Marks"], color='skyblue')
plt.title("Marks Bar Chart")
plt.xlabel("Student")
plt.ylabel("Marks")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x="Subject", data=df, palette="Set2")
plt.title("Subject Frequency")
plt.show()
# Out:
# C:\Users\Pandey's\AppData\Local\Temp\ipykernel_16928\1700430946.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Subject", data=df, palette="Set2")

# %%
plt.figure(figsize=(6, 4))
sns.histplot(df["Marks"], bins=5, kde=True, color='orange')
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x="Subject", y="Marks", data=df, palette="coolwarm")
plt.title("Marks Distribution by Subject")
plt.show()
# Out:
# C:\Users\Pandey's\AppData\Local\Temp\ipykernel_16928\798059727.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Subject", y="Marks", data=df, palette="coolwarm")

# %%
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap="YlGnBu")
plt.title("Correlation Heatmap")
plt.show()
